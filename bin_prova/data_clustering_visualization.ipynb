# %%
import os
import csv

import random
import numpy as np

from sklearn.manifold.t_sne import TSNE
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import PCA, TruncatedSVD
from collections import OrderedDict

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
f = open('outdir.txt', 'r')
outdir = f.read().rstrip('\n')
f = open('experiment_folder.txt', 'r')
experiment_folder = f.read().rstrip('\n')

##Read encoded vectors file and ordered medical record numbers
with open(experiment_folder + '/encoded_vect.csv') as f:
    rd = csv.reader(f)
    encoded_vect = []
    for r in rd:
        encoded_vect.append(list(map(float, r)))
        
with open(experiment_folder + '/mrns.csv') as f:
    rd = csv.reader(f)
    mrns = []
    for r in rd:
        mrns.append(r[0])

with open(outdir + '/cohort-new_ehr.csv') as f:
    rd = csv.reader(f)
    raw_ehr = {}
    for r in rd:
        raw_ehr.setdefault(r[0], list()).extend(list(map(int, r[1::])))

##padded raw data
raw_data = []
max_len = 0
for _, e in raw_ehr.items():
    raw_data.append(e)
    if len(e) >= max_len:
        max_len = len(e)
for idx, s in enumerate(raw_data):
    raw_data[idx] = s + [0]*(max_len-len(s))
    
##get list of first diagnosed diseases associated with mrns
with open(outdir + '/cohort-mrn_diseases.csv') as f:
    rd = csv.reader(f)
    mrn_disease = {}
    for r in rd:
        mrn_disease[r[0]] = r[1::]
        
mrn_encoded_disease = []
for m in mrns:
    mrn_encoded_disease.append(mrn_disease[m][0])

disease_dict = {}
idx = 0
for d in set(mrn_encoded_disease):
    disease_dict[d] = idx
    idx += 1

mrn_raw_disease = []
for m in raw_ehr:
    mrn_raw_disease.append(mrn_disease[m][0])

with open(outdir + '/cohort-new_vocab.csv') as f:
    rd = csv.reader(f)
    next(rd)
    new_vocab = {}
    for r in rd:
        new_vocab[r[1]] = r[0]
        
len_vocab = len(new_vocab)

# %%
def svd_tfidf(data, len_vocab):
    
    count_mat = np.zeros((len(data), len_vocab))
    
    for idx, token_list in enumerate(data):
        for t in token_list:
            if t != 0: ##we start the vocabulary from 1
                count_mat[idx, t-1] += 1
                
    tfidf = TfidfTransformer()
    tfidf_mat = tfidf.fit_transform(count_mat)
    
    svd = TruncatedSVD(n_components=32)
    svd_mat = svd.fit_transform(tfidf_mat)
    
    return svd_mat

##Hierarchical clustering function
def hclust_ehr(data, min_cl, max_cl, metric):
    best_silh = 0.0
    for n in range(min_cl,max_cl,1):
        hclust = AgglomerativeClustering(n_clusters=n, 
                                         linkage='complete', 
                                         affinity=metric)
        tmp_label = hclust.fit_predict(data).tolist()
        tmp_silh = silhouette_score(data, tmp_label)
        if tmp_silh > best_silh:
            best_silh = tmp_silh
            n_clust = n
            label = tmp_label
    print("Number of clusters found:{0}, Silhouette score:{1:.3f}".format(n_clust, best_silh))
    return n_clust, label

def svd_tfidf(data, len_vocab):
    
    count_mat = np.zeros((len(data), len_vocab))
    
    for idx, token_list in enumerate(data):
        for t in token_list:
            if t != 0: ##we start the vocabulary from 1
                count_mat[idx, t-1] += 1
                
    tfidf = TfidfTransformer()
    tfidf_mat = tfidf.fit_transform(count_mat)
    
    svd = TruncatedSVD(n_components=32)
    svd_mat = svd.fit_transform(tfidf_mat)
    
    return svd_mat

def FreqDict(tokens):
    freq_dict = {}
    for seq in tokens:
        for s in seq:
            if s not in freq_dict:
                freq_dict[s] = 1
            else:
                freq_dict[s] += 1
    return freq_dict

def freq_term(data, n_clusters, pred_class, n, term_list):
    encoded_groups = OrderedDict()
    encoded_seq = OrderedDict()
    for i in range(n_clusters):
        encoded_groups[i] = []
        encoded_seq[i] = []
        for j in range(len(pred_class)):
            if pred_class[j] == i:
                encoded_groups[i] += [mrns[j]]
                encoded_seq[i].append([rd for rd in data[j] if rd!=0 and (str.split(new_vocab[str(rd)], "::")[0] in term_list)])
                
    for cl in range(n_clusters):
        encoded_count = FreqDict(encoded_seq[cl])
        for l in range(n):
            MFMT = max(encoded_count, key=(lambda key: encoded_count[key]))
            num_MFMT = 0
            for el in data:
                for t in el:
                    if t == MFMT:
                        num_MFMT += 1
    
            print("Cluster {0} -- Relative numerosity of first most frequent term:{1} = {2:.2f}".format(cl,new_vocab[str(MFMT)], 
                                                                                                encoded_count[MFMT]/num_MFMT))
            encoded_count.pop(MFMT)
        print("\n")

# %%
##initialize T-SNE
tsne = TSNE(n_components=2, n_iter=5000, perplexity=50, random_state=42)
col_dict = matplotlib.colors.CSS4_COLORS
c_out = ['mintcream', 'cornsilk', 'lavenderblush', 'aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'powderblue', 'floralwhite', 'ghostwhite',
 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue',
 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'linen', 'palegoldenrod', 'palegreen', 'paleturquoise', 'palevioletred', 'papayawhip',
 'peachpuff', 'mistyrose', 'lemonchiffon', 'lightblue', 'seashell']
colormap = [c for c in col_dict if c not in c_out]

# %%
# for i, c in enumerate(colormap):
#     print(i, c)

# %% [markdown]
# ## Clustering CNN+AE encoded vectors

# %%
##run the TSNE on data
encoded_tsne = tsne.fit_transform(encoded_vect).tolist()

# %%
colors_en1 = [colormap[disease_dict[v]] for v in mrn_encoded_disease]

# %%
plt.figure(figsize=(20,10))
for cl in set(mrn_encoded_disease):
    x = [en[0] for j, en in enumerate(encoded_tsne) if mrn_encoded_disease[j]==cl]
    y = [en[1] for j, en in enumerate(encoded_tsne) if mrn_encoded_disease[j]==cl]
    cols = [c for j, c in enumerate(colors_en1) if mrn_encoded_disease[j]==cl]
    plt.scatter(x, y, c=cols, label=cl)
plt.legend()

# %%
##Apply hierarchical clustering to data
n_clust_en, label_en = hclust_ehr(encoded_vect, 4, 40, 'l1')
# Out:
# Number of clusters found:4, Silhouette score:0.390

# %%
colors_en2 = [colormap[v] for v in label_en]

# %%
plt.figure(figsize=(20,10))
for l in set(label_en):
    x = [en[0] for j, en in enumerate(encoded_tsne) if label_en[j]==l]
    y = [en[1] for j, en in enumerate(encoded_tsne) if label_en[j]==l]
    cols = [c for j, c in enumerate(colors_en2) if label_en[j]==l]
    plt.scatter(x, y, c=cols, label=l)
plt.legend()

# %%
freq_term(raw_data, n_clust_en, label_en, 10, ['icd9', 'medication'])
# Out:
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.27
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.23
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.31
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.27
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.33
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.20
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.19
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Unspecified delay in development::315.9::n/a = 0.29
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Obesity, unspecified::278.00::C0028754 = 0.24
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Cough::786.2::C0010200 = 0.35
#
#
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.47
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.54
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.63
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.65
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.44
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.52
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Dental examination::V72.2::C0490066 = 0.68
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.49
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.42
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.56
#
#
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.17
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.14
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Unspecified acquired hypothyroidism::244.9::C0020676 = 0.47
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.39
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.18
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.23
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.13
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Unspecified vitamin d deficiency::268.9::C0042870 = 0.34
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.14
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Obesity, unspecified::278.00::C0028754 = 0.17
#
#
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.09
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.39
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.21
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.10
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.17
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Obesity, unspecified::278.00::C0028754 = 0.19
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.11
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.10
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Unspecified delay in development::315.9::n/a = 0.11
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.08

# %% [markdown]
# ## Raw data

# %%
scaler = StandardScaler()
raw_data_scaled = scaler.fit_transform(raw_data)

# %%
# ##T-SNE
raw_tsne = tsne.fit_transform(raw_data_scaled)

# %%
colors_raw1 = [colormap[disease_dict[v]] for v in mrn_raw_disease]
plt.figure(figsize=(20,10))
for cl in set(mrn_raw_disease):
    x = [ra[0] for j, ra in enumerate(raw_tsne) if mrn_raw_disease[j]==cl]
    y = [ra[1] for j, ra in enumerate(raw_tsne) if mrn_raw_disease[j]==cl]
    cols = [c for j, c in enumerate(colors_raw1) if mrn_raw_disease[j]==cl]
    plt.scatter(x, y, c=cols, label=cl)
plt.legend()

# %%
n_clust_raw, label_raw = hclust_ehr(raw_data_scaled, 4, 40, 'cosine')
# Out:
# Number of clusters found:5, Silhouette score:0.203

# %%
colors_raw2 = [colormap[v] for v in label_raw]
plt.figure(figsize=(20,10))
for l in set(label_raw):
    x = [ra[0] for j, ra in enumerate(raw_tsne) if label_raw[j]==l]
    y = [ra[1] for j, ra in enumerate(raw_tsne) if label_raw[j]==l]
    cols = [c for j, c in enumerate(colors_raw2) if label_raw[j]==l]
    plt.scatter(x, y, c=cols, label=l)
plt.legend()

# %%
freq_term(raw_data, n_clust_raw, label_raw, 4, ['icd9', 'medication'])
# Out:
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.41
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.27
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.38
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.18
#
#
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.14
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.50
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.39
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.36
#
#
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.16
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.15
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.15
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.14
#
#
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.17
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.31
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.51
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.24
#
#
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.13
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.28
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.28
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.29

# %% [markdown]
# ## Count data

# %%
svd_mat = svd_tfidf(raw_data, len_vocab)

# %%
# ##T-SNE
count_tsne = tsne.fit_transform(svd_mat)

# %%
colors_count1 = [colormap[disease_dict[v]] for v in mrn_raw_disease]
plt.figure(figsize=(20,10))
for cl in set(mrn_raw_disease):
    x = [cou[0] for j, cou in enumerate(count_tsne) if mrn_raw_disease[j]==cl]
    y = [cou[1] for j, cou in enumerate(count_tsne) if mrn_raw_disease[j]==cl]
    cols = [c for j, c in enumerate(colors_count1) if mrn_raw_disease[j]==cl]
    plt.scatter(x, y, c=cols, label=cl)
plt.legend()

# %%
n_clust_count, label_count = hclust_ehr(svd_mat, 4, 40, 'cosine')
# Out:
# Number of clusters found:35, Silhouette score:0.170

# %%
colors_count2 = [colormap[v] for v in label_count]
plt.figure(figsize=(20,10))
for l in set(label_count):
    x = [cou[0] for j, cou in enumerate(count_tsne) if label_count[j]==l]
    y = [cou[1] for j, cou in enumerate(count_tsne) if label_count[j]==l]
    cols = [c for j, c in enumerate(colors_count2) if label_count[j]==l]
    plt.scatter(x, y, c=cols, label=l)
plt.legend()

# %%
freq_term(raw_data, n_clust_count, label_count, 4, ['icd9', 'medication'])
# Out:
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.07
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Other developmental speech or language disorder::315.39::C0154633 = 0.27
# Cluster 0 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.06
#
#
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.18
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.11
# Cluster 1 -- Relative numerosity of first most frequent term:icd9::Impulse control disorder, unspecified::312.30::C0021122 = 0.24
#
#
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.44
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.07
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.29
# Cluster 2 -- Relative numerosity of first most frequent term:icd9::Generalized convulsive epilepsy, without mention of intractable epilepsy::345.10::C0154709 = 0.45
#
#
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.12
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.05
# Cluster 3 -- Relative numerosity of first most frequent term:icd9::Other and unspecified special symptoms or syndromes, not elsewhere classified::307.9::C0302371 = 0.15
#
#
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.15
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Autoimmune hepatitis::571.42::C0241910 = 1.00
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.04
# Cluster 4 -- Relative numerosity of first most frequent term:icd9::Mild intellectual disabilities::317::C0026106 = 0.15
#
#
# Cluster 5 -- Relative numerosity of first most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.18
# Cluster 5 -- Relative numerosity of first most frequent term:icd9::Tuberous sclerosis::759.5::C0041341 = 1.00
# Cluster 5 -- Relative numerosity of first most frequent term:icd9::Unspecified acquired hypothyroidism::244.9::C0020676 = 0.18
# Cluster 5 -- Relative numerosity of first most frequent term:icd9::Proteinuria::791.0::C0033687 = 0.35
#
#
# Cluster 6 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 6 -- Relative numerosity of first most frequent term:icd9::Gender identity disorder in children::302.6::C0236802 = 1.00
# Cluster 6 -- Relative numerosity of first most frequent term:icd9::Posttraumatic stress disorder::309.81::C0038436 = 0.90
# Cluster 6 -- Relative numerosity of first most frequent term:icd9::Lack of normal physiological development, unspecified::783.40::C0878706 = 0.09
#
#
# Cluster 7 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.67
# Cluster 7 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 7 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.08
# Cluster 7 -- Relative numerosity of first most frequent term:icd9::Other developmental speech or language disorder::315.39::C0154633 = 0.05
#
#
# Cluster 8 -- Relative numerosity of first most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.86
# Cluster 8 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.04
# Cluster 8 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.14
# Cluster 8 -- Relative numerosity of first most frequent term:icd9::Unspecified acquired hypothyroidism::244.9::C0020676 = 0.31
#
#
# Cluster 9 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 9 -- Relative numerosity of first most frequent term:icd9::Unspecified vitamin d deficiency::268.9::C0042870 = 0.15
# Cluster 9 -- Relative numerosity of first most frequent term:icd9::Panhypopituitarism::253.2::C0242343 = 1.00
# Cluster 9 -- Relative numerosity of first most frequent term:icd9::Persistent disorder of initiating or maintaining sleep::307.42::C0868777 = 1.00
#
#
# Cluster 10 -- Relative numerosity of first most frequent term:icd9::Acute lymphoid leukemia, without mention of having achieved remission::204.00::C2349266 = 1.00
# Cluster 10 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.14
# Cluster 10 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.25
# Cluster 10 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
#
#
# Cluster 11 -- Relative numerosity of first most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.49
# Cluster 11 -- Relative numerosity of first most frequent term:icd9::Proteinuria::791.0::C0033687 = 0.39
# Cluster 11 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.05
# Cluster 11 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
#
#
# Cluster 12 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 12 -- Relative numerosity of first most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.30
# Cluster 12 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.06
# Cluster 12 -- Relative numerosity of first most frequent term:icd9::Other and unspecified special symptoms or syndromes, not elsewhere classified::307.9::C0302371 = 0.19
#
#
# Cluster 13 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 13 -- Relative numerosity of first most frequent term:icd9::Unspecified acquired hypothyroidism::244.9::C0020676 = 0.34
# Cluster 13 -- Relative numerosity of first most frequent term:icd9::Liver replaced by transplant::V42.7::C0023908 = 0.98
# Cluster 13 -- Relative numerosity of first most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.08
#
#
# Cluster 14 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.38
# Cluster 14 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.08
# Cluster 14 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.24
# Cluster 14 -- Relative numerosity of first most frequent term:icd9::Contact dermatitis and other eczema, unspecified cause::692.9::C0375487 = 0.34
#
#
# Cluster 15 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 15 -- Relative numerosity of first most frequent term:icd9::Severe intellectual disabilities::318.1::C0036857 = 0.11
# Cluster 15 -- Relative numerosity of first most frequent term:icd9::Profound intellectual disabilities::318.2::C3161330 = 0.18
# Cluster 15 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, residual state::299.01::C0338984 = 0.24
#
#
# Cluster 16 -- Relative numerosity of first most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.12
# Cluster 16 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 16 -- Relative numerosity of first most frequent term:icd9::Benign essential hypertension::401.1::C0155583 = 0.26
# Cluster 16 -- Relative numerosity of first most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.02
#
#
# Cluster 17 -- Relative numerosity of first most frequent term:icd9::Dental examination::V72.2::C0490066 = 0.32
# Cluster 17 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 17 -- Relative numerosity of first most frequent term:icd9::Localization-related (focal) (partial) epilepsy and epileptic syndromes with complex partial seizures, without mention of intractable epilepsy::345.40::C1306246 = 0.78
# Cluster 17 -- Relative numerosity of first most frequent term:icd9::Other specified disorders of amino-acid metabolism::270.8::C0029774 = 1.00
#
#
# Cluster 18 -- Relative numerosity of first most frequent term:icd9::Short stature::783.43::C0349588 = 0.67
# Cluster 18 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 18 -- Relative numerosity of first most frequent term:icd9::Pituitary dwarfism::253.3::C0013338 = 1.00
# Cluster 18 -- Relative numerosity of first most frequent term:icd9::Other atopic dermatitis and related conditions::691.8::C0494831 = 0.14
#
#
# Cluster 19 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.43
# Cluster 19 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 19 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.66
# Cluster 19 -- Relative numerosity of first most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.16
#
#
# Cluster 20 -- Relative numerosity of first most frequent term:icd9::Diabetes mellitus without mention of complication, type i [juvenile type], not stated as uncontrolled::250.01::C0375114 = 0.67
# Cluster 20 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 20 -- Relative numerosity of first most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.06
# Cluster 20 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.02
#
#
# Cluster 21 -- Relative numerosity of first most frequent term:icd9::Dysthymic disorder::300.4::C0013415 = 0.89
# Cluster 21 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.06
# Cluster 21 -- Relative numerosity of first most frequent term:icd9::Bipolar disorder, unspecified::296.80::C0005586 = 0.73
# Cluster 21 -- Relative numerosity of first most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.50
#
#
# Cluster 22 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.03
# Cluster 22 -- Relative numerosity of first most frequent term:icd9::Impulse control disorder, unspecified::312.30::C0021122 = 0.36
# Cluster 22 -- Relative numerosity of first most frequent term:icd9::Moderate intellectual disabilities::318.0::C0026351 = 0.40
# Cluster 22 -- Relative numerosity of first most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.05
#
#
# Cluster 23 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 23 -- Relative numerosity of first most frequent term:icd9::Bartter's syndrome::255.13::C0004775 = 1.00
# Cluster 23 -- Relative numerosity of first most frequent term:icd9::Feeding difficulties and mismanagement::783.3::C0699815 = 0.38
# Cluster 23 -- Relative numerosity of first most frequent term:icd9::Attention to gastrostomy::V55.1::C0260761 = 0.75
#
#
# Cluster 24 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.50
# Cluster 24 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.06
# Cluster 24 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.17
# Cluster 24 -- Relative numerosity of first most frequent term:icd9::Cough::786.2::C0010200 = 0.39
#
#
# Cluster 25 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 25 -- Relative numerosity of first most frequent term:icd9::Allergic rhinitis, cause unspecified::477.9::C2607914 = 0.18
# Cluster 25 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.05
# Cluster 25 -- Relative numerosity of first most frequent term:icd9::Contact dermatitis and other eczema, unspecified cause::692.9::C0375487 = 0.11
#
#
# Cluster 26 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 26 -- Relative numerosity of first most frequent term:icd9::Obsessive-compulsive disorders::300.3::C0028768 = 0.47
# Cluster 26 -- Relative numerosity of first most frequent term:icd9::Bipolar disorder, unspecified::296.80::C0005586 = 0.16
# Cluster 26 -- Relative numerosity of first most frequent term:icd9::Dysthymic disorder::300.4::C0013415 = 0.08
#
#
# Cluster 27 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 27 -- Relative numerosity of first most frequent term:icd9::Unspecified hyperkinetic syndrome::314.9::C1263846 = 0.19
# Cluster 27 -- Relative numerosity of first most frequent term:icd9::Lack of normal physiological development, unspecified::783.40::C0878706 = 0.03
# Cluster 27 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.01
#
#
# Cluster 28 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.06
# Cluster 28 -- Relative numerosity of first most frequent term:icd9::Congenital hydrocephalus::742.3::C0020256 = 1.00
# Cluster 28 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 28 -- Relative numerosity of first most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.19
#
#
# Cluster 29 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 29 -- Relative numerosity of first most frequent term:icd9::Explosive personality disorder::301.3::C0152183 = 0.20
# Cluster 29 -- Relative numerosity of first most frequent term:icd9::Unspecified nonpsychotic mental disorder::300.9::C0041857 = 0.07
# Cluster 29 -- Relative numerosity of first most frequent term:icd9::Generalized anxiety disorder::300.02::C0270549 = 0.33
#
#
# Cluster 30 -- Relative numerosity of first most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.42
# Cluster 30 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.07
# Cluster 30 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.01
# Cluster 30 -- Relative numerosity of first most frequent term:icd9::Major depressive affective disorder, single episode, unspecified::296.20::C0024517 = 0.43
#
#
# Cluster 31 -- Relative numerosity of first most frequent term:icd9::Obesity, unspecified::278.00::C0028754 = 0.36
# Cluster 31 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.04
# Cluster 31 -- Relative numerosity of first most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.08
# Cluster 31 -- Relative numerosity of first most frequent term:icd9::Acquired acanthosis nigricans::701.2::C0392440 = 0.50
#
#
# Cluster 32 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 32 -- Relative numerosity of first most frequent term:icd9::Other atopic dermatitis and related conditions::691.8::C0494831 = 0.24
# Cluster 32 -- Relative numerosity of first most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.05
# Cluster 32 -- Relative numerosity of first most frequent term:icd9::Dermatitis due to food taken internally::693.1::C0494843 = 0.49
#
#
# Cluster 33 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.02
# Cluster 33 -- Relative numerosity of first most frequent term:icd9::Kidney replaced by transplant::V42.0::C0677491 = 1.00
# Cluster 33 -- Relative numerosity of first most frequent term:icd9::Chronic kidney disease, stage i::585.1::C1561638 = 1.00
# Cluster 33 -- Relative numerosity of first most frequent term:icd9::Need for prophylactic immunotherapy::V07.2::C0260399 = 1.00
#
#
# Cluster 34 -- Relative numerosity of first most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.62
# Cluster 34 -- Relative numerosity of first most frequent term:icd9::Other specified pervasive developmental disorders, current or active state::299.80::C0154451 = 0.07
# Cluster 34 -- Relative numerosity of first most frequent term:icd9::Allergic rhinitis, cause unspecified::477.9::C2607914 = 0.09
# Cluster 34 -- Relative numerosity of first most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.00
